# %% [markdown]
# # API
#
# ## Definition
# API = Application Programming Interface • Application: Software programs • Programming: Code-based communication • Interface: A bridge that connects two systems
#
# ## Simple Analogies
#
# - Programmatically Talking to another External System.
#
# - There are Different types of API, but at this stage you just have to call the API's

# %% [markdown]
# ### Weather API

# %%
import requests

res=requests.get('https://p2pclouds.up.railway.app/v1/learn/weather?city=lahore')

# %%
data=res.json()

data
# Out:
# {'location': {'name': 'Lahore',
#   'region': 'Punjab',
#   'country': 'Pakistan',
#   'lat': 31.5497,
#   'lon': 74.3436,
#   'tz_id': 'Asia/Karachi',
#   'localtime_epoch': 1762202611,
#   'localtime': '2025-11-04 01:43'},
#  'current': {'last_updated_epoch': 1762201800,
#   'last_updated': '2025-11-04 01:30',
#   'temp_c': 20.4,
#   'temp_f': 68.7,
#   'is_day': 0,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#    'code': 1009},
#   'wind_mph': 8.1,
#   'wind_kph': 13,
#   'wind_degree': 108,
#   'wind_dir': 'ESE',
#   'pressure_mb': 1008,
#   'pressure_in': 29.77,
#   'precip_mm': 0,
#   'precip_in': 0,
#   'humidity': 73,
#   'cloud': 0,
#   'feelslike_c': 20.4,
#   'feelslike_f': 68.7,
#   'windchill_c': 20.8,
#   'windchill_f': 69.5,
#   'heatindex_c': 20.8,
#   'heatindex_f': 69.5,
#   'dewpoint_c': 5.5,
#   'dewpoint_f': 41.9,
#   'vis_km': 3.5,
#   'vis_miles': 2,
#   'uv': 0,
#   'gust_mph': 16.9,
# ...

# %%
data['current']
# Out:
# {'last_updated_epoch': 1762201800,
#  'last_updated': '2025-11-04 01:30',
#  'temp_c': 20.4,
#  'temp_f': 68.7,
#  'is_day': 0,
#  'condition': {'text': 'Overcast',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#   'code': 1009},
#  'wind_mph': 8.1,
#  'wind_kph': 13,
#  'wind_degree': 108,
#  'wind_dir': 'ESE',
#  'pressure_mb': 1008,
#  'pressure_in': 29.77,
#  'precip_mm': 0,
#  'precip_in': 0,
#  'humidity': 73,
#  'cloud': 0,
#  'feelslike_c': 20.4,
#  'feelslike_f': 68.7,
#  'windchill_c': 20.8,
#  'windchill_f': 69.5,
#  'heatindex_c': 20.8,
#  'heatindex_f': 69.5,
#  'dewpoint_c': 5.5,
#  'dewpoint_f': 41.9,
#  'vis_km': 3.5,
#  'vis_miles': 2,
#  'uv': 0,
#  'gust_mph': 16.9,
#  'gust_kph': 27.2}

# %%
data['location']
# Out:
# {'name': 'Lahore',
#  'region': 'Punjab',
#  'country': 'Pakistan',
#  'lat': 31.5497,
#  'lon': 74.3436,
#  'tz_id': 'Asia/Karachi',
#  'localtime_epoch': 1762202611,
#  'localtime': '2025-11-04 01:43'}

# %% [markdown]
# ##### For the Rest API there are 4 Methods of API Calling : GET, POST, PUT, DELETE
# For that read my blog on this: https://zeeshan.p2pclouds.net/blogs/what-is-rest-api/

# %% [markdown]
# ### Current IP Check

# %%
ip_res=requests.get('https://ipwho.is/')

# %%
id_data=ip_res.json()

# %%
id_data
# Out:
# {'ip': '182.189.25.71',
#  'success': True,
#  'type': 'IPv4',
#  'continent': 'Asia',
#  'continent_code': 'AS',
#  'country': 'Pakistan',
#  'country_code': 'PK',
#  'region': 'Islamabad Capital Territory',
#  'region_code': '',
#  'city': 'Islamabad',
#  'latitude': 33.7293882,
#  'longitude': 73.0931461,
#  'is_eu': False,
#  'postal': '44000',
#  'calling_code': '92',
#  'capital': 'Islamabad',
#  'borders': 'AF,CN,IN,IR',
#  'flag': {'img': 'https://cdn.ipwhois.io/flags/pk.svg',
#   'emoji': '🇵🇰',
#   'emoji_unicode': 'U+1F1F5 U+1F1F0'},
#  'connection': {'asn': 17557,
#   'org': 'Soft X',
#   'isp': 'Pakistan Telecommuication Company Limited',
#   'domain': 'ptcl.net.pk'},
#  'timezone': {'id': 'Asia/Karachi',
#   'abbr': 'PKT',
#   'is_dst': False,
#   'offset': 18000,
#   'utc': '+05:00',
#   'current_time': '2025-11-04T01:46:34+05:00'}}
